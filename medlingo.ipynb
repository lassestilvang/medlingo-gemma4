# %% [markdown]
# # MedLingo — Live Demo Setup
#
# This notebook sets up **MedLingo**, a private medical document assistant powered by **Gemma 4** running locally via Ollama.
#
# ### 💡 Prerequisite
# Go to **Runtime > Change runtime type** and ensure **T4 GPU** is selected.

# %% [markdown]
# ## 1. Clone & Setup
# First, we'll clone the repository and run the setup script to install Ollama and Gemma 4.

# %%
# Clone the repo (replace with your repo URL if different)
# !git clone https://github.com/lassestilvang/medlingo-gemma4.git
# %cd medlingo-gemma4

# Run the setup script
# !chmod +x setup_colab.sh
# !./setup_colab.sh

# %% [markdown]
# ## 2. Launch MedLingo
# We'll run the FastAPI server in the background and expose it using `localtunnel`.

# %%
import threading
import os
import time

def run_app():
    # !python app.py

# Start FastAPI in a background thread
threading.Thread(target=run_app, daemon=True).start()

time.sleep(3)

print("\n--- 🌐 PUBLIC DEMO URL ---")
print("Click the link below and then click 'Browse to website' if prompted.")
print("Note: You may need to enter the IP address of this Colab instance (found by running !curl ifconfig.me)")
# !npx localtunnel --port 8000
